# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions

# %%
dataset = pd.read_csv("C:/Users/sumit/OneDrive/Documents/polynomial_classification_data.csv")
dataset.head(3)
# Out:
#       data1     data2  output
# 0 -0.501840  0.568127       0
# 1  1.802857 -1.663440       1
# 2  0.927976 -1.353485       0

# %%
dataset.isnull().sum()
# Out:
# data1     0
# data2     0
# output    0
# dtype: int64

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(data=dataset,x="data1",y="data2",hue="output")
plt.show()

# %%
x=dataset.iloc[:,:-1]
y=dataset["output"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2 , random_state =42)

# %%
from sklearn.svm import SVC

# %%
#rbf is best work here

# %%
sv = SVC(kernel = "rbf")
sv.fit(x_train,y_train)
# Out:
# SVC()

# %%
sv.score(x_test,y_test)*100 , sv.score(x_train,y_train)*100
# Out:
# (97.5, 98.75)

# %%
plot_decision_regions(x.to_numpy() , y.to_numpy() ,clf=sv)
plt.show()
# Out:
# C:\Users\sumit\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
