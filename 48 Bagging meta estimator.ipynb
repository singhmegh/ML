# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_moons

# %%
x,y = make_moons(n_samples = 1000,noise = 0.2)

# %%
df = {"x1":x[:,0],"x2":x[:,1],"y":y}

# %%
dataset = pd.DataFrame(df)

# %%
dataset
# Out:
#            x1        x2  y
# 0    0.946966  0.202048  0
# 1    1.192084  0.583969  0
# 2   -0.086334  0.921409  0
# 3    1.998171 -0.208222  1
# 4    0.641092  0.804601  0
# ..        ...       ... ..
# 995 -0.384542  0.879589  0
# 996  0.746374 -0.377537  1
# 997 -1.115429  0.565941  0
# 998  0.441468 -0.398484  1
# 999 -0.632148  1.106350  0
#
# [1000 rows x 3 columns]

# %%
sns.scatterplot(data=dataset,x="x1",y="x2",hue="y")
plt.show()

# %%
x_a = dataset.iloc[:,:-1]
y_a = dataset["y"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x_a,y_a,test_size = 0.2,random_state = 42)

# %% [markdown]
# # Bagging model

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
bg = BaggingClassifier(estimator=SVC(),n_estimators=50)
bg.fit(x_train,y_train)
# Out:
# BaggingClassifier(estimator=SVC(), n_estimators=50)

# %%
bg.score(x_train,y_train)*100 , bg.score(x_test,y_test)*100
# Out:
# (97.125, 96.0)

# %% [markdown]
# # Random forest model

# %%
rf = RandomForestClassifier(n_estimators = 30)
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=30)

# %%
rf.score(x_train,y_train)*100 , rf.score(x_test,y_test)*100
# Out:
# (99.75, 96.5)
