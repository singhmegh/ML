# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv("C:/Users/sumit/Downloads/placement.csv")
dataset.head(3)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25

# %%
dataset.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
x = dataset[["cgpa"]]
y = dataset["package"]

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(data = dataset , x = "cgpa",y="package")
plt.show()

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict([[7.89]])
# Out:
# C:\Users\sumit\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.50387663])

# %%
lr.score(x_test,y_test)*100         #accuracy
# Out:
# 77.30984312051673

# %%
y_prd = lr.predict(x)

# %%
plt.figure(figsize=(5,4))
sns.scatterplot(data = dataset , x = "cgpa",y="package",label = "org")
plt.plot(dataset["cgpa"],y_prd ,c="red")
plt.legend(["org_data","predict_line"])
plt.show()
