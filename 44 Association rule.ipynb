# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option("display.max_rows",200)

# %%
dataset = pd.read_csv("C:/Users/sumit/OneDrive/Desktop/groceries1.csv")
dataset.head(3)
# Out:
#            Item 1               Item 2    Item 3        Item 4 Item 5 Item 6  \
# 0    citrus fruit  semi-finished bread  margarine  ready soups    NaN    NaN
# 1  tropical fruit               yogurt     coffee          NaN    NaN    NaN
# 2      whole milk                  NaN        NaN          NaN    NaN    NaN
#
#   Item 7 Item 8 Item  9 Item 10   ... Unnamed: 22 Unnamed: 23 Unnamed: 24  \
# 0    NaN    NaN     NaN      NaN  ...         NaN         NaN         NaN
# 1    NaN    NaN     NaN      NaN  ...         NaN         NaN         NaN
# 2    NaN    NaN     NaN      NaN  ...         NaN         NaN         NaN
#
#   Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28 Unnamed: 29 Unnamed: 30  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 31
# 0         NaN
# 1         NaN
# ...

# %%
dataset.columns
# Out:
# Index(['Item 1', 'Item 2', 'Item 3 ', 'Item 4', 'Item 5', 'Item 6', 'Item 7',
#        'Item 8', 'Item  9', 'Item 10 ', 'Item 11', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31'],
#       dtype='object')

# %%
dataset.shape ,new_data.shape
# Out:
# ((9835, 32), (9835, 11))

# %%
new_data = dataset[['Item 1', 'Item 2', 'Item 3 ', 'Item 4', 'Item 5', 'Item 6', 'Item 7',
       'Item 8', 'Item  9', 'Item 10 ', 'Item 11']].copy()

# %% [markdown]
# # make a list of lists in market

# %%
market = []
for i in range (0,new_data.shape[0]):           #Loops through each row 
    cus =[]
    for j in new_data.columns:                  #Loops through each columns
        if type(new_data[j][i])==str:
            cus.append(new_data[j][i])
    market.append(cus)

# %% [markdown]
# # make single list by market

# %%
l = []
for i in market:                  #Har customer ki shopping list (i) lega.
    for j in i:                   #Us shopping list ke har item (j) ko lega
        l.append(j)

# %%
import collections

# %%
p = collections.Counter(l)

# %%
d = {"Item Name":p.keys(),"Values":p.values()}

# %%
pd.DataFrame(d).sort_values(by=["Values"],ascending = False)
# Out:
#                      Item Name  Values
# 7                   whole milk    2513
# 11            other vegetables    1903
# 17                  rolls/buns    1787
# 31                        soda    1634
# 5                       yogurt    1367
# 42             root vegetables    1072
# 24               bottled water    1041
# 4               tropical fruit    1032
# 50                     sausage     924
# 52               shopping bags     876
# 39                      pastry     854
# 0                 citrus fruit     814
# 19                bottled beer     752
# 49                 canned beer     749
# 8                    pip fruit     744
# 35                  newspapers     717
# 60          whipped/sour cream     702
# 34       fruit/vegetable juice     630
# 51                 brown bread     625
# 65               domestic eggs     609
# 30                 frankfurter     580
# 58                        pork     567
# 2                    margarine     550
# ...

# %% [markdown]
# # make a matrix of item

# %%
from mlxtend.preprocessing.transactionencoder import TransactionEncoder

# %%
tr =TransactionEncoder()
tr.fit(market)
# Out:
# TransactionEncoder()

# %%
df = pd.DataFrame(tr.transform(market),columns=tr.columns_)

# %%
df.head(3)
# Out:
#    Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                  False     False             False             False
# 1                  False     False             False             False
# 2                  False     False             False             False
#
#    baby cosmetics   bags  baking powder  bathroom cleaner   beef  berries  \
# 0           False  False          False             False  False    False
# 1           False  False          False             False  False    False
# 2           False  False          False             False  False    False
#
#    ...  turkey  vinegar  waffles  whipped/sour cream  whisky  white bread  \
# 0  ...   False    False    False               False   False        False
# 1  ...   False    False    False               False   False        False
# 2  ...   False    False    False               False   False        False
#
#    white wine  whole milk  yogurt  zwieback
# ...

# %%
from mlxtend.frequent_patterns import apriori

# %%
apriori(df,min_support = 0.05,use_colnames = True,max_len = 3).sort_values("support")
# Out:
#      support                        itemsets
# 0   0.052466                          (beef)
# 8   0.052974                          (curd)
# 7   0.054398                        (coffee)
# 28  0.054906        (whole milk, rolls/buns)
# 4   0.055313                        (butter)
# 29  0.055618            (whole milk, yogurt)
# 12  0.055923                     (margarine)
# 17  0.057651                          (pork)
# 10  0.058973                   (frankfurter)
# 9   0.061922                 (domestic eggs)
# 3   0.063549                   (brown bread)
# 11  0.064057         (fruit/vegetable juice)
# 24  0.071378            (whipped/sour cream)
# 13  0.072903                    (newspapers)
# 27  0.074835  (other vegetables, whole milk)
# 16  0.075648                     (pip fruit)
# 5   0.076157                   (canned beer)
# 1   0.076462                  (bottled beer)
# 6   0.082766                  (citrus fruit)
# 15  0.086833                        (pastry)
# ...

# %%
# best pair (other vegetables, whole milk)
